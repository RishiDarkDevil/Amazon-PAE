# %% [markdown]
# ## Loading Necessary Libraries

# %%
# general
import re
import gc
import os
import csv
import time
import math
import pickle
from tqdm import tqdm

# data handling
import numpy as np
import pandas as pd

# HTML parsing
from bs4 import BeautifulSoup

# plotting
import matplotlib.pyplot as plt

# chunker
import torch
from torch import cuda

# NLP
import nltk.corpus
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import spacy
from bertopic import BERTopic
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/rishideychowdhury/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/rishideychowdhury/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ## Load Data

# %%
# 2023
# data = pd.read_csv('../data/2023/train-v3.csv', usecols=['BULLET_POINTS'])
data = pd.read_csv('../data/2023/train-v3.csv', usecols=['PRODUCT_TYPE_ID', 'DESCRIPTION'])

# %%
data = data.fillna('')

# %%
# data = data.to_numpy().tolist()

# %%
# data = pd.DataFrame([' . '.join([str(bp) for bp in bps if str(bp) != '']) for bps in data])

# %%
# data

# %%
data = data[~data.iloc[:,0].isin([''])]

# %%
# data_bps_idxs = data.index.to_list()

# %%
data
# Out:
#                                                DESCRIPTION  PRODUCT_TYPE_ID
# 2        Specifications : Color : Red , Material : Alum...             7537
# 3        AISHAH Women ' s Lycra Cotton Ankel Leggings ....             2996
# 5        HINS Brings you the most Elegant Looking Pot w...             5725
# 7        Aluminum Foil Stickers-good kitchen helper for...             6030
# 9        Transform your home , workplace or hotel room ...             8201
# ...                                                    ...              ...
# 2249688  Welcome to the wonderfully Wicked World of Aut...              123
# 2249689  This extra long Tall t-Shirt will be your favo...             2879
# 2249694  [ Brand ] : XVIEONR [ Product name ] : Fashion...             3413
# 2249695  Wall Clocks Are Very Attractive In Looks And E...             1574
# 2249697  Skyjacker C7360SP Component Box For PN [ C7360...             7367
#
# [1092187 rows x 2 columns]

# %% [markdown]
# ## Cleaning

# %%
# define function to clean text

stop = stopwords.words('english')

lemmatizer = WordNetLemmatizer()

def clean_text(text):

  text = text.lower()
  text = re.sub(r"(@\[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", text) # Punctuations, URLs and @
  text = " ".join([word for word in text.split() if word not in (stop)]) # Stopwords
  text = " ".join([lemmatizer.lemmatize(word) for word in text.split()]) # Stemming
  
  return(text)

# %%
data_prod = data[data.PRODUCT_TYPE_ID == 1650]
data_prod
# Out:
#                                                DESCRIPTION  PRODUCT_TYPE_ID
# 491      STORE99 Acrylic Crystal Butterfly Beads Curtai...             1650
# 618      WHY COZY FURNISH CURTAINS : Our premium cotton...             1650
# 1152     3NH Hotel Decoration Window Thickened Yarn Cor...             1650
# 1375     This curtain enhances the look of the interior...             1650
# 2437     Curtains : Set of 3 Long Door Curtains , Mater...             1650
# ...                                                    ...              ...
# 2246662  Don ’ t let the sunlight wake you up when you ...             1650
# 2246765  GlobalNiche Modern Velvet Solid Blackout Curta...             1650
# 2247261  Gdr Curtains Add A Touch Of Sophistication To ...             1650
# 2247730  Bring home happiness with finest quality of Cu...             1650
# 2249517  Description : Made of high quality polyester m...             1650
#
# [3539 rows x 2 columns]

# %%
data_sub = data_prod[['DESCRIPTION']].copy(deep = True)
data_sub = data_sub.applymap(clean_text)
data_sub
# Out:
#                                                DESCRIPTION
# 491      store99 acrylic crystal butterfly bead curtain...
# 618      cozy furnish curtain premium cotton linen look...
# 1152     3nh hotel decoration window thickened yarn cor...
# 1375     curtain enhances look interior curtain made 10...
# 2437     curtain set 3 long door curtain material crush...
# ...                                                    ...
# 2246662  let sunlight wake want liein instead look blac...
# 2246765  globalniche modern velvet solid blackout curta...
# 2247261  gdr curtain add touch sophistication living be...
# 2247730  bring home happiness finest quality curtain so...
# 2249517  description made high quality polyester materi...
#
# [3539 rows x 1 columns]

# %% [markdown]
# ## Topic Modelling

# %%
docs_product_desc = data_sub.DESCRIPTION
nlp = spacy.load('en_core_web_sm', exclude=['tagger', 'parser', 'ner', 'attribute_ruler', 'lemmatizer'])

# %%
topic_model_product_desc = BERTopic(embedding_model=nlp, nr_topics=10)
topics, probs = topic_model_product_desc.fit_transform(docs_product_desc)

# %%
fig = topic_model_product_desc.visualize_topics()
fig.show()
# Out:
# <div>                            <div id="d901d0cd-f6bf-4748-83c5-36ea0a4d605e" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d901d0cd-f6bf-4748-83c5-36ea0a4d605e")) {                    Plotly.newPlot(                        "d901d0cd-f6bf-4748-83c5-36ea0a4d605e",                        [{"customdata":[[0,"curtain | room | home | panel | decor",1516],[1,"curtain | room | fabric | quality | polyester",968],[2,"inch | cm | 52 | curtain | foot",158],[3,"curtain | room | dreaming | casa | panel",143],[4,"product | curtain | door | 48 | quality",96],[5,"curtain | measure | always | track | pinch",54],[6,"best | inspired | home | galaxy | brand",31],[7,"4feet | many | curtain | available | pre",27],[8,"door48inch | inch | known | 48inch | lighter",21]],"hovertemplate":"<b>Topic %{customdata[0]}</b><br>%{customdata[1]}<br>Size: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[1516,968,158,143,96,54,31,27,21],"sizemode":"area","sizeref":0.9475,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[6.641218185424805,6.098748207092285,6.2806077003479,8.140073776245117,5.3137712478637695,5.887911319732666,9.052083015441895,5.7575249671936035,8.71487045288086],"xaxis":"x","y":[11.579498291015625,11.652024269104004,10.783490180969238,10.937103271484375,10.312856674194336,10.242310523986816,10.237914085388184,9.626270294189453,10.545273780822754],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111 ...

# %%
topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True)
topics, probs = topic_model.fit_transform(docs_product_desc.to_list())
# Out:
# Batches:   0%|          | 0/111 [00:00<?, ?it/s]
# 2023-05-29 04:45:12,382 - BERTopic - Transformed documents to Embeddings
# 2023-05-29 04:45:20,066 - BERTopic - Reduced dimensionality
# 2023-05-29 04:45:21,401 - BERTopic - Clustered reduced embeddings

# %%
freq = topic_model.get_topic_info(); freq.head(5)
# Out:
#    Topic  Count                                    Name
# 0     -1    589             -1_curtain_window_size_room
# 1      0    119  0_market_enhances_engaged_organization
# 2      1     89       1_globalniche_tulle_cortina_blind
# 3      2     88        2_outdoor_blackout_energy_triple
# 4      3     69               3_heat_liein_999_blackout

# %%
topic_model.get_topic(0)  # Select the most frequent topic
# Out:
# [('market', 0.08032821562935667),
#  ('enhances', 0.0603748181441646),
#  ('engaged', 0.059099876078665306),
#  ('organization', 0.059099876078665306),
#  ('loving', 0.0588552926460896),
#  ('demand', 0.05873422936075664),
#  ('rate', 0.05794783041124989),
#  ('competitive', 0.05723016885592878),
#  ('reputed', 0.05723016885592878),
#  ('romantic', 0.055236848594538354)]

# %%
topic_model.topics_[:10]
# Out:
# [1, 27, 1, 0, 5, 13, 21, 8, -1, 98]

# %%
topic_model.visualize_topics()
# Out:
# <div>                            <div id="b8efafdf-d707-49bc-9f84-34d69e161363" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8efafdf-d707-49bc-9f84-34d69e161363")) {                    Plotly.newPlot(                        "b8efafdf-d707-49bc-9f84-34d69e161363",                        [{"customdata":[[0,"market | enhances | engaged | organization | loving",119],[1,"globalniche | tulle | cortina | blind | drape",89],[2,"outdoor | blackout | energy | triple | summer",88],[3,"heat | liein | 999 | blackout | instead",69],[4,"welcoming | layered | sleek | aware | ability",65],[5,"foot | shrink | fastness | caters | wash",65],[6,"kiara | upgraded | beyond | ordinary | pleasant",64],[7,"amp | linen | grihshobha | tone | shop",58],[8,"approx | note | description | specification | quot",48],[9,"fast | material | crush | reactive | premium",47],[10,"gothic | visually | unlike | sheen | online",47],[11,"95 | brushed | microfiber | lightweight | set",42],[12,"sassy | define | bringing | resistance | contemporary",42],[13,"problem | jacquard | jute | plain | solve",41],[14,"market | organization | engaged | loving | demand",40],[15,"thy | tranquil | laid | pas | feelig",39],[16,"done | cloth | printing | usual | sharp",39],[17,"hung | finishing | richness | another | via",36],[18,"brushed | microfiber | set | lightweight | 84",34],[19,"happiness | soulful | intersection | affordability | amazing",34],[20,"ability | aware | make | space | break",33],[21,"expert | workmanship | content | installed | fine",32],[22,"3d | digital | foot | 48 | door",32],[23,"utsav | varying | including | today | construction",32],[24,"varying | including | today | silk | construction",32],[25,"48inch | lighter | stitched | door48inch | perfection",30],[26,"breathe | surrounding | splash | character | pleasing",29],[27,"52 | 135 | inch | cm | width",28],[28,"presenting | usable | purchasing | amazures | minimise",28],[29,"inspired | galaxy | best | brand | formed",28],[30,"textile | softalker | store | factory | supermarket",27],[31,"contemporary | modern | variety | industrial | limitless",27],[32,"yukany | cm | transparency | 4x5 | 122x213",27],[33,"striking | contrast | softly | bit | eyecatching",26],[34,"52 | inch | versailtex | blackout | x2022",26],[35,"dreaming | casa | nice | good | giving",26],[36,"ambience | several | crushed | pas | amount",25],[37,"always | pinch | track | 15 | remember",25],[38,"inner | rsquo | minimalism | liner | simplicity",25],[39,"ability | welcoming | sleek | layered | aware",24],[40,"upmarket | orderly | shiny | slide | install",24],[41,"order | click | custom | width | retardant",23],[42,"grommet | panel | 54 | textured | canvas",23],[43,"48 | waterfall | highest | product | door",23],[44,"fabdrape | favourite | maker | specialist | via",23],[45,"maintained | extremely | sophistication | fine | getting",23],[46,"worrying | semitransparent | putting | smartly | cheerful",22],[47,"4feet | many | shape | rectangular | square",22],[48,"shading | effect | 50 | maximum | dark",22],[49,"blackout | 260 | styleworth | light | drawn",22],[50,"sateen | pleat | pinch | dimeter | thermax",22],[51,"pattern | upgraded | ved | beyond | ordinary",22],[52,"house | purchasing | sweet | worthy | investment",22],[53,"smell | toxic | azofree | nearly | weave",22],[54,"63 | brushed | microfiber | lightweight | set",22],[55,"castle | fab | multiple | boasting | blowing",21],[56,"newturn | kid | textile | deep | designed",21],[57,"brushed | microfiber | measurements56 | lightweight | kid",21],[58,"fresh | loom | managing | premade | finish",21],[59,"inch | insulated | option | point | 46x24",20],[60,"value | nurture | challenged | lucacci | evolved",20],[61,"60inch | inch | panel | voile | 84inch",20],[62,"h ...

# %%
topic_model.get_document_info(docs_product_desc)
# Out:
#                                                Document  Topic
# 0     store99 acrylic crystal butterfly bead curtain...      1  \
# 1     cozy furnish curtain premium cotton linen look...     27
# 2     3nh hotel decoration window thickened yarn cor...      1
# 3     curtain enhances look interior curtain made 10...      0
# 4     curtain set 3 long door curtain material crush...      5
# ...                                                 ...    ...
# 3534  let sunlight wake want liein instead look blac...      3
# 3535  globalniche modern velvet solid blackout curta...      1
# 3536  gdr curtain add touch sophistication living be...    111
# 3537  bring home happiness finest quality curtain so...     19
# 3538  description made high quality polyester materi...      8
#
#                                                  Name
# 0                   1_globalniche_tulle_cortina_blind  \
# 1                                   27_52_135_inch_cm
# 2                   1_globalniche_tulle_cortina_blind
# 3              0_market_enhances_engaged_organization
# 4                       5_foot_shrink_fastness_caters
# ...                                               ...
# 3534                        3_heat_liein_999_blackout
# 3535                1_globalniche_tulle_cortina_blind
# 3536                      111_gdr_foot_stitching_door
# 3537  19_happiness_soulful_intersection_affordability
# 3538          8_approx_note_description_specification
#
#                                             Top_n_words  Probability
# 0     globalniche - tulle - cortina - blind - drape ...     0.032718  \
# 1     52 - 135 - inch - cm - width - length - 63inch...     0.026296
# 2     globalniche - tulle - cortina - blind - drape ...     0.255184
# 3     market - enhances - engaged - organization - l...     0.385787
# 4     foot - shrink - fastness - caters - wash - soa...     0.021353
# ...                                                 ...          ...
# 3534  heat - liein - 999 - blackout - instead - wake...     1.000000
# 3535  globalniche - tulle - cortina - blind - drape ...     0.119192
# 3536  gdr - foot - stitching - door - making - clean...     1.000000
# 3537  happiness - soulful - intersection - affordabi...     1.000000
# 3538  approx - note - description - specification - ...     0.135974
#
#       Representative_document
# 0                       False
# 1                       False
# 2                       False
# 3                        True
# 4                       False
# ...                       ...
# 3534                     True
# 3535                    False
# 3536                    False
# 3537                     True
# 3538                    False
#
# [3539 rows x 6 columns]

# %%
topic_model.get_document_info(docs_product_desc).iloc[0,0]
# Out:
# 'store99 acrylic crystal butterfly bead curtain diy window door curtain party wedding crystal bead curtain passage decoration zh01572'

# %%
topic_model.get_document_info(docs_product_desc).iloc[0,3]
# Out:
# 'globalniche - tulle - cortina - blind - drape - sheer - voile - purple - bedroom - green'
